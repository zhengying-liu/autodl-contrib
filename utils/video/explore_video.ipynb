# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import os
import sys
sys.path.append('../')
from dataset_formatter import UniMediaDatasetFormatter

import re
from pprint import pprint
from sklearn.utils import shuffle # For shuffling datasets

# %%
import cv2 # Run `pip install opencv-python` to install
import matplotlib.pyplot as plt
import matplotlib.animation as animation
# %matplotlib qt5

# %%
def parse_filename(filename):
  """
  Args:
    filename: e.g. 'person01_running_d1_uncomp.avi'
  Returns:
    e.g. 'person01_running_d1', '01', 'running', 'd1'
  """
  FILENAME_PATTERN = r'(person(\d+)_(\w+)_(d\d))_uncomp.avi'
  res = re.match(FILENAME_PATTERN, filename)
  if res:
    basename, person_id, action, remark = res.groups()
    person_id = int(person_id)
    return basename, person_id, action, remark
  else:
    raise ValueError("Filename not in good pattern!")

def get_kth_info_df(kth_dir, tmp_dir='/tmp/', from_scratch=False):
  csv_filepath = os.path.join(tmp_dir, 'kth_files_info.csv')
  if not from_scratch and os.path.isfile(csv_filepath):
    kth_df = pd.read_csv(csv_filepath)
    print("Successfully loaded existing info table. Now life is easier.")
    return kth_df
  else:
    print("Couldn't load existing info table. Now building from scatch...")
    train_id = [11, 12, 13, 14, 15, 16, 17, 18]
    valid_id = [19, 20, 21, 23, 24, 25, 1, 4]
    test_id = [22, 2, 3, 5, 6, 7, 8, 9, 10]
    train_id = train_id + valid_id # Merge training set and validation set

    def get_subset(person_id):
      """
      Returns:
        'train' or 'test'
      """
      if person_id in train_id:
        return 'train'
      elif person_id in test_id:
        return 'test'
      else:
        raise ValueError(f"Wrong person id {person_id}!")

    path = kth_dir
    li = []
    for dirpath, dirnames, filenames in os.walk(path):
      for filename in filenames:
        if filename.endswith('.avi'):
          basename, person_id, action, remark = parse_filename(filename)
          video_filepath = os.path.join(dirpath, filename)
          subset = get_subset(person_id)
          li.append((basename, person_id, action, remark, video_filepath, subset))
    kth_df = pd.DataFrame({'basename':        [x[0] for x in li],
                           'person_id':       [x[1] for x in li],
                           'action':          [x[2] for x in li],
                           'remark':          [x[3] for x in li],
                           'video_filepath':  [x[4] for x in li],
                           'subset':          [x[5] for x in li]})
    kth_df['action'] = kth_df['action'].astype('category')
    kth_df['action_num'] = kth_df['action'].cat.codes
    kth_df['remark'] = kth_df['remark'].astype('category')
    kth_df['remark_num'] = kth_df['remark'].cat.codes

    kth_df.to_csv(csv_filepath, index=False)
    return kth_df

# %%
def video_to_3d_features(video_filepath, resize=(1,1)):
  cap = cv2.VideoCapture(video_filepath)
  features = []
  printed = False
  while(cap.isOpened()):
    ret, frame = cap.read()
    if not ret:
      break
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    height, width = gray.shape
    fx, fy = resize
    new_height = int(fx * height)
    new_width = int(fx * width)
    if not printed and resize != (1,1):
      print('Resizing video from original size {} to new size {}...'.format((height, width), (new_height, new_width)))
      printed = True
    gray_resized = cv2.resize(gray, (new_width, new_height))
    gray_flattened = gray_resized.flatten()
    features.append(gray_flattened)
  cap.release()
  cv2.destroyAllWindows()
  features = np.array(features)
  return features

def play_video_from_file(filename):
  fig, ax = plt.subplots()
  vidcap = cv2.VideoCapture(filename)
  success,image = vidcap.read()
  image = np.array(image).astype(float)
  screen = plt.imshow(image)
  def init():  # only required for blitting to give a clean slate.
      screen.set_data(np.empty(image.shape))
      return screen,
  def animate(i):
      if vidcap.isOpened():
        success,image = vidcap.read()
        image = np.array(image).astype(float)
        screen.set_data(image)
      return screen,
  ani = animation.FuncAnimation(
      fig, animate, init_func=init, interval=40, blit=True, save_count=50, repeat=False) # interval=40 because 25fps
  plt.show()
  return ani, plt

def play_video_from_features(features, row_count=120, col_count=160, interval=80, resize=(1,1)):
  fig, ax = plt.subplots()
  new_row_count = int(row_count * resize[0])
  new_col_count = int(col_count * resize[1])
  print('Playing with {} rows and {} columns.'.format(new_row_count, new_col_count))
  image = features[0].reshape((new_row_count, new_col_count))
  screen = plt.imshow(image, cmap='gray')
  def init():  # only required for blitting to give a clean slate.
      screen.set_data(np.empty(image.shape))
      return screen,
  def animate(i):
      if i < len(features):
        image = features[i].reshape((new_row_count, new_col_count))
        screen.set_data(image)
      return screen,
  ani = animation.FuncAnimation(
      fig, animate, init_func=init, interval=interval, blit=True, save_count=50, repeat=False) # interval=40 because 25fps
  plt.show()
  return ani, plt

# %%
kth_dir = '../../raw_datasets/video/kth/'
df = get_kth_info_df(kth_dir)
# Out:
# Successfully loaded existing info table. Now life is easier.

# %%
filepath = np.random.choice(df['video_filepath'])
print('filepath:', filepath)
# Out:
# filepath: ../../raw_datasets/video/kth/handwaving/person10_handwaving_d4_uncomp.avi

# %%
resize = (0.5,0.5)
features = video_to_3d_features(filepath, resize=resize)
print(features.shape)
play_video_from_features(features, interval=40, resize=resize)
# Out:
# Resizing video from original size (120, 160) to new size (60, 80)...
# (532, 4800)
# Playing with 60 rows and 80 columns.
# (<matplotlib.animation.FuncAnimation at 0x1304202e8>,
#  <module 'matplotlib.pyplot' from '/Users/evariste/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py'>)

# %%
df
# Out:
#            action                  basename  person_id remark subset  \
# 0         running       person11_running_d1         11     d1  train
# 1         running       person16_running_d2         16     d2  train
# 2         running       person21_running_d4         21     d4  train
# 3         running       person07_running_d1          7     d1   test
# 4         running       person08_running_d2          8     d2   test
# 5         running       person19_running_d1         19     d1  train
# 6         running       person15_running_d3         15     d3  train
# 7         running       person05_running_d4          5     d4   test
# 8         running       person13_running_d4         13     d4  train
# 9         running       person03_running_d3          3     d3   test
# 10        running       person24_running_d2         24     d2  train
# 11        running       person23_running_d1         23     d1  train
# 12        running       person09_running_d3          9     d3   test
# 13        running       person19_running_d4         19     d4  train
# 14        running       person13_running_d1         13     d1  train
# 15        running       person23_running_d4         23     d4  train
# 16        running       person14_running_d2         14     d2  train
# 17        running       person02_running_d2          2     d2   test
# 18        running       person25_running_d3         25     d3  train
# 19        running       person05_running_d1          5     d1   test
# 20        running       person17_running_d3         17     d3  train
# 21        running       person07_running_d4          7     d4   test
# 22        running       person11_running_d4         11     d4  train
# 23        running       person01_running_d3          1     d3  train
# 24        running       person21_running_d1         21     d1  train
# 25        running       person01_running_d4          1     d4  train
# 26        running       person11_running_d3         11     d3  train
# 27        running       person20_running_d2         20     d2  train
# 28        running       person07_running_d3          7     d3   test
# 29        running       person17_running_d4         17     d4  train
# ..            ...                       ...        ...    ...    ...
# 569  handclapping  person09_handclapping_d3          9     d3   test
# 570  handclapping  person05_handclapping_d3          5     d3   test
# 571  handclapping  person10_handclapping_d2         10     d2   test
# 572  handclapping  person06_handclapping_d2          6     d2   test
# 573  handclapping  person02_handclapping_d1          2     d1   test
# 574  handclapping  person13_handclapping_d4         13     d4  train
# 575  handclapping  person09_handclapping_d4          9     d4   test
# 576  handclapping  person18_handclapping_d1         18     d1  train
# 577  handclapping  person14_handclapping_d1         14     d1  train
# 578  handclapping  person05_handclapping_d4          5     d4   test
# 579  handclapping  person21_handclapping_d1         21     d1  train
# 580  handclapping  person08_handclapping_d3          8     d3   test
# 581  handclapping  person04_handclapping_d3          4     d3  train
# 582  handclapping  person11_handclapping_d2         11     d2  train
# 583  handclapping  person24_handclapping_d2         24     d2  train
# 584  handclapping  person07_handclapping_d2          7     d2   test
# 585  handclapping  person12_handclapping_d3         12     d3  train
# 586  handclapping  person20_handclapping_d3         20     d3  train
# 587  handclapping  person19_handclapping_d3         19     d3  train
# 588  handclapping  person15_handclapping_d3         15     d3  train
# 589  handclapping  person23_handclapping_d2         23     d2  train
# 590  handclapping  person03_handclapping_d3          3     d3   test
# 591  handclapping  person16_handclapping_d2         16     d2  train
# 592  handclapping  person02_handclapping_d4          2     d4   test
# 593  handclapping  person13_handclapping_d1         13     d1  train
# 594  handclapping  person21_handclapping_d4         21     d4  train
# 595  handclapping  person09_handclapping_d1          9     d1   test
# 596  handclapping  person18_handclapping_d4         18     d4  train
# 597  handclapping  person14_handclapping_d4         14     d4  train
# 598  handclapping  person05_handclapping_d1          5     d1   test
#
#                                         video_filepath  action_num  remark_num
# 0    ../../raw_datasets/video/kth/running/person11_...           4           0
# 1    ../../raw_datasets/video/kth/running/person16_...           4           1
# 2    ../../raw_datasets/video/kth/running/person21_...           4           3
# 3    ../../raw_datasets/video/kth/running/person07_...           4           0
# 4    ../../raw_datasets/video/kth/running/person08_...           4           1
# 5    ../../raw_datasets/video/kth/running/person19_...           4           0
# 6    ../../raw_datasets/video/kth/running/person15_...           4           2
# 7    ../../raw_datasets/video/kth/running/person05_...           4           3
# 8    ../../raw_datasets/video/kth/running/person13_...           4           3
# 9    ../../raw_datasets/video/kth/running/person03_...           4           2
# 10   ../../raw_datasets/video/kth/running/person24_...           4           1
# 11   ../../raw_datasets/video/kth/running/person23_...           4           0
# 12   ../../raw_datasets/video/kth/running/person09_...           4           2
# 13   ../../raw_datasets/video/kth/running/person19_...           4           3
# 14   ../../raw_datasets/video/kth/running/person13_...           4           0
# 15   ../../raw_datasets/video/kth/running/person23_...           4           3
# 16   ../../raw_datasets/video/kth/running/person14_...           4           1
# 17   ../../raw_datasets/video/kth/running/person02_...           4           1
# 18   ../../raw_datasets/video/kth/running/person25_...           4           2
# 19   ../../raw_datasets/video/kth/running/person05_...           4           0
# 20   ../../raw_datasets/video/kth/running/person17_...           4           2
# 21   ../../raw_datasets/video/kth/running/person07_...           4           3
# 22   ../../raw_datasets/video/kth/running/person11_...           4           3
# 23   ../../raw_datasets/video/kth/running/person01_...           4           2
# 24   ../../raw_datasets/video/kth/running/person21_...           4           0
# 25   ../../raw_datasets/video/kth/running/person01_...           4           3
# 26   ../../raw_datasets/video/kth/running/person11_...           4           2
# 27   ../../raw_datasets/video/kth/running/person20_...           4           1
# 28   ../../raw_datasets/video/kth/running/person07_...           4           2
# 29   ../../raw_datasets/video/kth/running/person17_...           4           3
# ..                                                 ...         ...         ...
# 569  ../../raw_datasets/video/kth/handclapping/pers...           1           2
# 570  ../../raw_datasets/video/kth/handclapping/pers...           1           2
# 571  ../../raw_datasets/video/kth/handclapping/pers...           1           1
# 572  ../../raw_datasets/video/kth/handclapping/pers...           1           1
# 573  ../../raw_datasets/video/kth/handclapping/pers...           1           0
# 574  ../../raw_datasets/video/kth/handclapping/pers...           1           3
# 575  ../../raw_datasets/video/kth/handclapping/pers...           1           3
# 576  ../../raw_datasets/video/kth/handclapping/pers...           1           0
# 577  ../../raw_datasets/video/kth/handclapping/pers...           1           0
# 578  ../../raw_datasets/video/kth/handclapping/pers...           1           3
# 579  ../../raw_datasets/video/kth/handclapping/pers...           1           0
# 580  ../../raw_datasets/video/kth/handclapping/pers...           1           2
# 581  ../../raw_datasets/video/kth/handclapping/pers...           1           2
# 582  ../../raw_datasets/video/kth/handclapping/pers...           1           1
# 583  ../../raw_datasets/video/kth/handclapping/pers...           1           1
# 584  ../../raw_datasets/video/kth/handclapping/pers...           1           1
# 585  ../../raw_datasets/video/kth/handclapping/pers...           1           2
# 586  ../../raw_datasets/video/kth/handclapping/pers...           1           2
# 587  ../../raw_datasets/video/kth/handclapping/pers...           1           2
# 588  ../../raw_datasets/video/kth/handclapping/pers...           1           2
# 589  ../../raw_datasets/video/kth/handclapping/pers...           1           1
# 590  ../../raw_datasets/video/kth/handclapping/pers...           1           2
# 591  ../../raw_datasets/video/kth/handclapping/pers...           1           1
# 592  ../../raw_datasets/video/kth/handclapping/pers...           1           3
# 593  ../../raw_datasets/video/kth/handclapping/pers...           1           0
# 594  ../../raw_datasets/video/kth/handclapping/pers...           1           3
# 595  ../../raw_datasets/video/kth/handclapping/pers...           1           0
# 596  ../../raw_datasets/video/kth/handclapping/pers...           1           3
# 597  ../../raw_datasets/video/kth/handclapping/pers...           1           3
# 598  ../../raw_datasets/video/kth/handclapping/pers...           1           0
#
# [599 rows x 8 columns]
